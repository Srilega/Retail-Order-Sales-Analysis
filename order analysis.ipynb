# %%
#!pip install kaggle
import kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\huawei\anaconda3\lib\site-packages (1.7.4.2)
# Requirement already satisfied: bleach in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: charset-normalizer in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (2.0.4)
# Requirement already satisfied: idna in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (3.4)
# Requirement already satisfied: protobuf in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (6.30.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (68.0.0)
# Requirement already satisfied: six>=1.10 in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (4.65.0)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (1.26.16)
# Requirement already satisfied: webencodings in c:\users\huawei\anaconda3\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: packaging in c:\users\huawei\anaconda3\lib\site-packages (from bleach->kaggle) (23.1)
# Requirement already satisfied: colorama in c:\users\huawei\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !kaggle --version
# Out:
# Kaggle API 1.7.4.2

# %%
# !kaggle datasets download -d ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !kaggle datasets download -d ankitbansal06/retail-orders --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading retail-orders.zip to C:\Users\HUAWEI\Documents\Python + SQL
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 79.7MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('retail-orders.zip')
zip_ref.extractall()
zip_ref.close()

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\huawei\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\huawei\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\huawei\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\huawei\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\huawei\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\huawei\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
df= pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
df.head(5)
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')

# %%
df.head(5)
# Out:
#    Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  cost_price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    Discount_Percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
df.columns = df.columns.astype(str).str.lower()

# %%
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
df['discount']=df['list_price']*df['discount_percent']*0.01

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount
# 0                    2       5.2
# 1                    3      21.9
# 2                    5       0.5
# 3                    2      19.2
# 4                    5       1.0
# ...                ...       ...
# 9989                 4       1.2
# 9990                 4       3.6
# 9991                 2       5.2
# 9992                 3       0.9
# 9993                 3       7.2
#
# [9994 rows x 17 columns]

# %%
df['sales_price']=df['list_price']-df['discount']

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sales_price
# 0                    2       5.2        254.8
# 1                    3      21.9        708.1
# 2                    5       0.5          9.5
# 3                    2      19.2        940.8
# 4                    5       1.0         19.0
# ...                ...       ...          ...
# 9989                 4       1.2         28.8
# 9990                 4       3.6         86.4
# 9991                 2       5.2        254.8
# 9992                 3       0.9         29.1
# 9993                 3       7.2        232.8
#
# [9994 rows x 18 columns]

# %%
df['profit']=df['sales_price']-df['cost_price']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cost_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df['profit']=df['sales_price']-df['cost_price']
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'cost_price'

# %%
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sales_price  profit
# 0                    2       5.2        254.8    14.8
# 1                    3      21.9        708.1   108.1
# 2                    5       0.5          9.5    -0.5
# 3                    2      19.2        940.8   160.8
# 4                    5       1.0         19.0    -1.0
# ...                ...       ...          ...     ...
# 9989                 4       1.2         28.8    -1.2
# 9990                 4       3.6         86.4    16.4
# 9991                 2       5.2        254.8    34.8
# 9992                 3       0.9         29.1    -0.9
# 9993                 3       7.2        232.8    22.8
#
# [9994 rows x 19 columns]

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# sales_price         float64
# profit              float64
# dtype: object

# %%
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")

# %%
df.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# discount                   float64
# sales_price                float64
# profit                     float64
# dtype: object

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True,errors='ignore')

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  quantity  discount  sales_price  profit
# 0       Bookcases  FUR-BO-10001798         2       5.2        254.8    14.8
# 1          Chairs  FUR-CH-10000454         3      21.9        708.1   108.1
# 2          Labels  OFF-LA-10000240         2       0.5          9.5    -0.5
# 3          Tables  FUR-TA-10000577         5      19.2        940.8   160.8
# 4         Storage  OFF-ST-10000760         2       1.0         19.0    -1.0
# ...           ...              ...       ...       ...          ...     ...
# 9989  Furnishings  FUR-FU-10001889         3       1.2         28.8    -1.2
# 9990  Furnishings  FUR-FU-10000747         2       3.6         86.4    16.4
# 9991       Phones  TEC-PH-10003645         2       5.2        254.8    34.8
# 9992        Paper  OFF-PA-10004041         4       0.9         29.1    -0.9
# 9993   Appliances  OFF-AP-10002684         2       7.2        232.8    22.8
#
# [9994 rows x 16 columns]

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\huawei\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\huawei\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\huawei\anaconda3\lib\site-packages (1.1.1)

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\huawei\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users
MB/s eta 0:00:05
#    ------------------- -------------------- 7.6/16.1 MB 2.1 MB/s eta 0:00:05
#    ------------------- -------------------- 7.8/16.1 MB 2.1 MB/s eta 0:00:04
#    ------------------- -------------------- 8.0/16.1 MB 2.1 MB/s eta 0:00:04
#    -------------------- ------------------- 8.1/16.1 MB 2.1 MB/s eta 0:00:04
#    -------------------- ------------------- 8.3/16.1 MB 2.1 MB/s eta 0:00:04
#    -------------------- ------------------- 8.4/16.1 MB 2.1 MB/s eta 0:00:04
#    --------------------- ------------------ 8.6/16.1 MB 2.2 MB/s eta 0:00:04
#    --------------------- ------------------ 8.8/16.1 MB 2.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.9/16.1 MB 2.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.1/16.1 MB 2.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.2/16.1 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.4/16.1 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ------------------------ --------------- 9.7/16.1 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 9.8/16.1 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 10.0/16.1 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 10.0/16.1 MB 2.3 MB/s eta 0:00:03
#    ------------------------- -------------- 10.2/16.1 MB 2.3 MB/s eta 0:00:03
#    ------------------------- -------------- 10.4/16.1 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 10.6/16.1 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 10.8/16.1 MB 2.3 MB/s eta 0:00:03
#    --------------------------- ------------ 11.0/16.1 MB 2.3 MB/s eta 0:00:03
#    --------------------------- ------------ 11.1/16.1 MB 2.3 MB/s eta 0:00:03
#    --------------------------- ------------ 11.2/16.1 MB 2.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.4/16.1 MB 2.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.8/16.1 MB 2.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 12.0/16.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 12.4/16.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.5/16.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.9/16.1 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 13.0/16.1 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 13.2/16.1 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 13.4/16.1 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 13.7/16.1 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 14.0/16.1 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.3/16.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/16.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/16.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 15.2/16.1 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/16.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.7/16.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.9/16.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.2.0

# %%
from sqlalchemy import create_engine
import mysql.connector

# %%
mysql+mysqlconnector://<username>:<password>@<host>/<database>
# Out:
#   Cell In[72], line 1
#     mysql+mysqlconnector://<username>:<password>@<host>/<database>
#                         ^
# SyntaxError: invalid syntax

# %%
username = 'root'
password = 'root'
host = '127.0.0.1'  # 'localhost' or IP address
database = 'retailorder'

# Create the engine
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}/{database}')

# %%
df.to_sql('df_orders',con=engine ,index=False ,if_exists='append')
# Out:
# 9994

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sales_price', 'profit'],
#       dtype='object')

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  quantity  discount  sales_price  profit
# 0       Bookcases  FUR-BO-10001798         2       5.2        254.8    14.8
# 1          Chairs  FUR-CH-10000454         3      21.9        708.1   108.1
# 2          Labels  OFF-LA-10000240         2       0.5          9.5    -0.5
# 3          Tables  FUR-TA-10000577         5      19.2        940.8   160.8
# 4         Storage  OFF-ST-10000760         2       1.0         19.0    -1.0
# ...           ...              ...       ...       ...          ...     ...
# 9989  Furnishings  FUR-FU-10001889         3       1.2         28.8    -1.2
# 9990  Furnishings  FUR-FU-10000747         2       3.6         86.4    16.4
# 9991       Phones  TEC-PH-10003645         2       5.2        254.8    34.8
# 9992        Paper  OFF-PA-10004041         4       0.9         29.1    -0.9
# 9993   Appliances  OFF-AP-10002684         2       7.2        232.8    22.8
#
# [9994 rows x 16 columns]
